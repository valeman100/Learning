# %% [markdown]
# # Character-Level Bigram Model

# %% [markdown]
# ![Status](https://img.shields.io/static/v1.svg?label=Status&message=Finished&color=brightgreen)
# [![Source](https://img.shields.io/static/v1.svg?label=GitHub&message=Source&color=181717&logo=GitHub)](https://github.com/particle1331/inefficient-networks/blob/master/docs/notebooks/tensorflow/05-tensorflow-cnn.ipynb)
# [![Stars](https://img.shields.io/github/stars/particle1331/inefficient-networks?style=social)](https://github.com/particle1331/inefficient-networks)
#
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook, we use a dataset of names to train a bigram character-level language model. This model can be used to generate new names (e.g. using a Markov process). The focus is on introducing the overall framework of language modeling that includes probabilistic modeling, model training, sampling, and the evaluation of models using a loss function (e.g. the negative log-likelihood for classification). Probabilities of bigrams will be modeled by (1) counting and (2) using a simple neural network with a single hidden layer.
#
# This notebook is based on [this tutorial](https://www.youtube.com/watch?v=PaCmpygFfXo) by [Andrej Karpathy](https://karpathy.ai/) on language modeling.

# %%
import math
import warnings
import matplotlib.pyplot as plt
from pathlib import Path
from matplotlib_inline import backend_inline
from typing import *

DATASET_DIR = Path("./data").absolute()
RANDOM_SEED = 42

warnings.simplefilter(action="ignore")
backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# ## The names dataset

# %% [markdown]
# First, we get the dataset of names that we will model:

# %%
names = open('names.txt', 'r').read().splitlines()
print(len(names))
names[:10]
# Out:
# 32033
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %% [markdown]
# A name is simply a sequence of characters. The task of **language modeling** is to assign probabilities to a sequence of characters. Our dataset which consists of over 32,000 names has a lot of structure both local (character level) and global (name level).
#
# Note that our names are not infinite sequences &mdash; it has a start and an end. So we have to have tokens for these delimiters. Moreover, most names have zero probability of occuring, i.e. names with the end token before the start token. We will develop a weak model which essentially models a [Markov process](https://en.wikipedia.org/wiki/Markov_chain) of length 1. To do this, we will use **bigrams**. Bigrams of the first name in the dataset are:

# %%
for name in names[:1]:
    chars = ['<S>'] + list(name) + ['<E>']
    for c1, c2 in zip(chars, chars[1:]):
        print(c1, c2)
# Out:
# <S> e
# e m
# m m
# m a
# a <E>

# %% [markdown]
# ### Generating *n*-grams

# %% [markdown]
# Since we will be working with larger contexts, e.g. trigrams, we want to define classes for helping with working with sequences of characters of arbitrary length. First, we define maps for encoding (and the corresponding decoding) of sequences to integers. This section will start to make sense as we go along the notebook.

# %%
from itertools import product
import functools

chars = ['.'] + sorted(list(set(''.join(names))))
itos = dict(enumerate(chars))
stoi = {c: i for i, c in itos.items()}

@functools.lru_cache()
def itox(context_size):
    return dict(enumerate(map(lambda z: ''.join(z), product(stoi.keys(), repeat=context_size))))

@functools.lru_cache()
def xtoi(context_size):
    return {x: i for i, x in itox(context_size).items()}

# %% [markdown]
# Observe that we don't really need two different characters for start and end of a name. This is because we can bound a name between using a single delimiter symbol. In the above class, we use `.` as a special character for padding names.

# %%
print(stoi['.'], stoi['a'], stoi['b'])
print(itos[0], itos[1], itos[2])
# Out:
# 0 1 2
# . a b

# %%
print(xtoi(2)['..'], xtoi(2)['.a'], xtoi(2)['zz'])
print(itox(2)[0], itox(2)[1], itox(2)[728])
# Out:
# 0 1 728
# .. .a zz

# %% [markdown]
# Note that given a context of size 2, we can pad all names with `..` on the left and `.` on the right. This convention works for all names and unambiguously denotes the start and end of a word. This is reflected on the following class which generates all subsequences of characters $\langle\boldsymbol{\mathsf x}_{t-n+1}, \ldots,\boldsymbol{\mathsf x}_{t}\rangle$ and the next character $\boldsymbol{\mathsf x}_{t+1}$ from a name $\boldsymbol{\mathsf x}.$

# %%
def build_dataset(context_size=1):
    """Creating subsequences -> next character target."""
    xs = []
    ys = []
    for i, name in enumerate(names):
        context = ['.'] * context_size
        for c in name + '.':
            xs.append(xtoi(context_size)[''.join(context)])
            ys.append(stoi[c])
            context = context[1:] + [c]
    return xs, ys

# %% [markdown]
# Generating sequences with context size 3. Notice that the start of a word is denoted by `...`. The code generates substrings by appending a sliding context with the next character.

# %%
import pandas as pd

xs, ys = build_dataset(context_size=3)

df = pd.DataFrame({'xs': xs, 'ys': ys})
df['seq'] = df['xs'].map(itox(3))
df['target'] = df['ys'].map(itos)
df.head(12)
# Out:
#        xs  ys  seq target
# 0       0   5  ...      e
# 1       5  13  ..e      m
# 2     148  13  .em      m
# 3    4009   1  emm      a
# 4    9829   0  mma      .
# 5       0  15  ...      o
# 6      15  12  ..o      l
# 7     417   9  .ol      i
# 8   11268  22  oli      v
# 9    9013   9  liv      i
# 10   7164   1  ivi      a
# 11  16282   0  via      .

# %% [markdown]
# ## Counting bigrams

# %% [markdown]
# To structure the data better, we use a 2D array. An entry `[i, j]` in this array is the count of bigrams that start with the `i`th character followed by the `j`th character. Also, we incorporate the fact that a single delimiter suffices. That is, we can use a `.` to signify the start of a name which will be closed by another `.` to signify the end of a name. Iterating over all names to get all existing bigrams:

# %%
import torch

xs, ys = build_dataset(context_size=1) # bigrams == context_size=1

# Create count matrix
N = torch.zeros((27, 27), dtype=torch.int32)
for x, y in zip(xs, ys):
    N[x, y] += 1

# Visualize count matrix
plt.figure(figsize=(16, 16))
plt.imshow(N, cmap='Blues')
for x in range(N.shape[0]):
    for y in range(N.shape[1]):
        chstr = itos[x] + itos[y]
        plt.text(y, x, chstr, ha="center", va="bottom", color='gray')
        plt.text(y, x, N[x, y].item(), ha="center", va="top", color='gray')

plt.axis('off');

# %% [markdown]
# ### Generating names
#
# Already at this point we can generate names. Recall that to model joint distributions, we can use a [chain of probabilities](https://d2l.ai/chapter_recurrent-neural-networks/sequence.html#markov-models). But conditioning only on the last character as a form of truncation. First, we sample the first character from the distribution conditioned on the start token. Going from there, we sample each character conditioned on the previous sampled character until we reach the end token.

# %%
def generate_names(P, context_size, sample_size, seed=2147483647):
    """Generate names from a Markov process with cond probability table P."""

    g = torch.Generator().manual_seed(seed)
    names = []
    for _ in range(sample_size):
        out = []
        context = '.' * context_size
        while True:
            i = xtoi(context_size)[context]
            j = torch.multinomial(P[i], num_samples=1, replacement=True, generator=g).item()
            if j == 0:
                break
            context = context[1:] + itos[j]
            out.append(itos[j])
        names.append(''.join(out))
    return names

# %% [markdown]
# Generating names from the conditional distributions estimated by counting:

# %%
P = N / N.sum(dim=1, keepdim=True)
for name in generate_names(P, 1, sample_size=10):
    print(name)
# Out:
# mor
# axx
# minaymoryles
# kondlaisah
# anchshizarie
# odaren
# iaddash
# h
# jhinatien
# egushl

# %% [markdown]
# Trying out trigrams (i.e. window size of 2):

# %%
xs, ys = build_dataset(context_size=2)

N2 = torch.zeros((27*27, 27), dtype=torch.int32)
for x, y in zip(xs, ys):
    N2[x, y] += 1

P2 = N2 / N2.sum(dim=1, keepdim=True)
for name in generate_names(P2, 2, sample_size=10, seed=42):
    print(name)
# Out:
# abbandys
# adesten
# mel
# mak
# aya
# aidalinmakey
# jazoe
# mckeandy
# hel
# nah

# %% [markdown]
# Note that modeling using bigrams is pretty bad. But it still looks better than random. Trigrams improve a bit. One reason this is bad is that the next most probable bigram has probability that drops exponentially from the last. This is known as [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law). Interestingly, this empirical law holds even for trigrams, and even for [word-level language modeling](https://d2l.ai/chapter_recurrent-neural-networks/text-sequence.html#exploratory-language-statistics).

# %%
fig, ax = plt.subplots(1, 2, figsize=(6, 3))
ax[0].plot(sorted(N.reshape(-1), reverse=True))
ax[1].plot(sorted(N2.reshape(-1), reverse=True), color='C1')
ax[0].set_title('Bigrams')
ax[1].set_title('Trigrams')
fig.tight_layout()

# %% [markdown]
# ### Model quality: MLE = NLL loss

# %% [markdown]
# To measure model quality we use [maximum likelihood estimation](https://d2l.ai/chapter_appendix-mathematics-for-deep-learning/maximum-likelihood.html#the-maximum-likelihood-principle) (MLE). That is, we choose model parameters $\boldsymbol{\Theta}$ that maximizes the probability of the dataset. For our character-level language model, our objective will be to maximize the probability assigned by the model to the next character:
#
# $$
# \hat p(\boldsymbol{\mathsf{x}}_{t} \mid \boldsymbol{\mathsf{x}}_1, \ldots, \boldsymbol{\mathsf{x}}_{t-1}; \boldsymbol{\Theta}).
# $$
#
# From the perspective of optimization, it is better to take the negative logarithm of the probability which increases rapidly as the probability goes to zero and has a nonzero derivative even as the probability goes to 1. This is really nice from the perspective of optimization. Thus, the following loss function called the **negative log-likelihood** is equivalent to next-character MLE, but easier to optimize:
#
# $$
# \mathcal{L}(\boldsymbol{\Theta}) = \frac{1}{n} \sum_{\boldsymbol{\mathsf{x}}} \sum_t -\log\, \hat p(\boldsymbol{\mathsf{x}}_{t} \mid \boldsymbol{\mathsf{x}}_1, \ldots, \boldsymbol{\mathsf{x}}_{t-1}; \boldsymbol{\Theta})
# $$
#
# where $n$ is the total number of characters to predict. Let us compute the NLL of the bigram model after fitting it on the counts. Note that bigram models assign probability using only the previous character, i.e. $\hat p(\boldsymbol{\mathsf{x}}_{t} \mid \boldsymbol{\mathsf{x}}_1, \ldots, \boldsymbol{\mathsf{x}}_{t-1}; \boldsymbol{\Theta}) = f(\boldsymbol{\mathsf{x}}_{t-1}; \boldsymbol{\Theta}).$

# %%
class BigramModel:
    def __init__(self):
        """
        Sequence model that uses bigrams / Markov process 
        for estimating probability of next char: P(b | a).
        """
        self.P = None  # cond. prob
        self.N = None  # counts

    def __call__(self, x: int):
        return torch.tensor([self.P[x, y] for y in range(27)])

    def fit(self, xs, ys):
        self.N = torch.zeros((27, 27), dtype=torch.int32)
        for x, y in zip(xs, ys):
            self.N[x, y] += 1

        self.P = self.N / self.N.sum(dim=1, keepdim=True)

# %% [markdown]
# Training the model on input and target sequences:

# %%
xs, ys = build_dataset(context_size=1)

# Fitting the bigram model
bigram_model = BigramModel()
bigram_model.fit(xs, ys)

# %% [markdown]
# Computing the NLL of the bigram model:

# %%
log_likelihood = 0.0
n = 0
for x, y in zip(xs, ys):
    p = bigram_model(x)[y]
    log_p = torch.log(p)
    log_likelihood += log_p
    n += 1
    if n < 12:
        print(f'p({itos[y]}|{itos[x]})={p:.4f}    nll={-log_p:.4f}')

nll = -log_likelihood
print('...')
print(f"nll = {nll / n:.4f} (overall)")
# Out:
# p(e|.)=0.0478    nll=3.0408
# p(m|e)=0.0377    nll=3.2793
# p(m|m)=0.0253    nll=3.6772
# p(a|m)=0.3899    nll=0.9418
# p(.|a)=0.1960    nll=1.6299
# p(o|.)=0.0123    nll=4.3982
# p(l|o)=0.0780    nll=2.5508
# p(i|l)=0.1777    nll=1.7278
# p(v|i)=0.0152    nll=4.1867
# p(i|v)=0.3541    nll=1.0383
# p(a|i)=0.1381    nll=1.9796
# ...
# nll = 2.4541 (overall)

# %% [markdown]
# A model that assigns a probability of `1.0` for each next actual character has a perfect NLL of exactly `0.0`. Here our bigram model gets penalized for next characters whose bigrams from the previous character occurs rarely on the training dataset.

# %% [markdown]
# ### Smoothing

# %% [markdown]
# Note that the loss can result in `+inf` when this encounters a bigram with zero counts in the training data, e.g. the name `gopde` since the bigram `pd` never appears on the training data. One way to fix this is to perform **model smoothing**. This can be done by adding a fixed constant to the counts:

# %% [markdown]
# ```python
# a = 2
# P = (N + a).float() / (N + a).sum(dim=1, keepdim=True)
# ```

# %% [markdown]
# The larger the constant `a`, the more uniform the resulting probabilities are. Hence, the term smoothing.

# %% [markdown]
# ## Modeling probabilities with a neural network

# %% [markdown]
# A neural network layer typically involves multiplication between the input vector and the weights matrix. So we design our neural network to have a single layer with weights $\boldsymbol{\mathsf W}$ of size `(27, 27)` that corresponds to the count matrix above. The relevant row of weights is picked out by computing $\boldsymbol{\mathsf w}_a = \boldsymbol{\mathsf x}_a \boldsymbol{\mathsf W}$ where $\boldsymbol{\mathsf x}_a$ is the one-hot encoding of the input character $a.$ Then, we apply softmax to $\boldsymbol{\mathsf w}_a$ which is a common technique for converting real-valued vectors to probabilities.
#
# This model still uses bigrams, but the assignment of conditional probabilities is estimated by initializing random weights which are fine-tuned using gradient descent such that the probabilities of the actual next characters are maximized.

# %%
import torch.nn.functional as F

xs = torch.tensor(xs)
ys = torch.tensor(ys)

xenc = F.one_hot(xs, num_classes=27).float() # convert to float
plt.imshow(xenc[:5, :]); # 0, 5, 13, 13, 1, ...

# %%
g = torch.Generator().manual_seed(2147483647)
W = torch.randn((27, 27), generator=g, requires_grad=True)

probs = F.softmax(xenc @ W)
probs.shape

# %%
plt.figure(figsize=(5, 3))
plt.bar(stoi.keys(), probs[0].data);

# %% [markdown]
# Observe that the weights with values in `(-inf, +inf)` can be interpreted as **log-counts** of bigrams that start on the row index. Applying `.exp()` we get units of count with values in `(0, +inf)`. These values are normalized to get an output vector with values in `(0, 1)` which we interpret as a probability distribution. Training the network will make these interpretations valid. This is implemented as follows:

# %%
class NNBigramModel:
    def __init__(self, seed=2147483647):
        self.g = torch.Generator().manual_seed(seed)
        self.W = torch.randn((27, 27), generator=self.g, requires_grad=True)

    def __call__(self, xs: list[int]) -> list[float]:
        xenc = F.one_hot(xs, num_classes=27).float()
        logits = xenc @ self.W                         # init => log-counts
        counts = logits.exp()                          # .exp() => counts
        probs = counts / counts.sum(1, keepdim=True)   # normalizing => probability
        return probs
        
    def zero_grad(self):
        self.W.grad = None

    def optim_step(self, lr):
        self.W.data -= lr * self.W.grad

# %% [markdown]
# ```{figure} ../../img/bigram-nn.drawio.svg
# ---
# width: 450px
# name: bigram-nn.drawio
# ---
#
# Schematic diagram of the bigram neural net. Computing the probability assigned by the model on `b` given `a` which is represented here as one-hot vector. Note that this is also the backward dependence for a bigram `ab` encountered during training with the NLL loss.
# ```

# %% [markdown]
# **Remark.** Note that the output of the model is specified by 729 numbers, i.e. one distribution over the characters for each character. This is a pretty weak model (essentially a lookup table). What will change with further networks is how to compute and assign probabilities to the next character. This will require more complex neural network architecture that reflect a different prior for the character dependencies.

# %% [markdown]
# ### Model training

# %% [markdown]
# This should converge to a similar loss value as the bigram counting model (same capacity):

# %%
model = NNBigramModel()

losses = []
num_steps = 100
for k in range(num_steps):
    probs = model(xs)
    loss = -probs[torch.arange(len(ys)), ys].log().mean()  # next char nll

    model.zero_grad()
    loss.backward()
    model.optim_step(lr=100.0)
    
    # logging
    losses.append(loss.item())
    if k % 10 == 9:
        print(f"[{k+1:>03d}/{num_steps}]   loss={loss:.4f}")
# Out:
# [010/100]   loss=2.6075
# [020/100]   loss=2.5346
# [030/100]   loss=2.5162
# [040/100]   loss=2.5025
# [050/100]   loss=2.5004
# [060/100]   loss=2.4930
# [070/100]   loss=2.4942
# [080/100]   loss=2.4887
# [090/100]   loss=2.4910
# [100/100]   loss=2.4863

# %%
plt.plot(losses)
plt.ylabel('loss')
plt.xlabel('step');

# %% [markdown]
# ### Sampling

# %% [markdown]
# Generating names and its associated NLL:

# %%
counts = model.W.exp()
P_nn = counts / counts.sum(dim=1, keepdim=True)

def name_loss(name, context_size, P):
    nll = 0.0
    context = '.' * context_size
    for c in name + '.':
        p = P[xtoi(context_size)[context], stoi[c]]
        nll += -math.log(p)
        context = context[1:] + c
    return nll / (len(name) + 1)


sample = generate_names(P_nn, context_size=1, sample_size=10)
name_losses = {n: name_loss(n, 1, P_nn) for n in sample}
for n in sorted(sample, key=lambda n: name_losses[n]):
    print(f"{n:<22} {name_losses[n]:.3f}")
# Out:
# mor                    2.369
# h                      2.378
# odarenamaidash         2.382
# jiondrienakayrer       2.434
# ays                    2.471
# mineymoryles           2.480
# memthizarie            2.634
# kongn                  2.720
# isaka                  2.751
# gaeu                   3.638

# %% [markdown]
# Recall that instead of maximizing names, we are maximizing next character likelihood. This explains why we get short names such as `'h'` and long names `'odarenamaidash'` with low NLL. Consequently, it is very likely that the generated names are not in the training dataset:

# %%
print(r"Generated names in training dataset:")
sample_size = 10000
print(f"{100 * sum([n in names for n in generate_names(P_nn, context_size=1, sample_size=sample_size)]) / sample_size}% (sample_size={sample_size})")
# Out:
# Generated names in training dataset:
# 8.03% (sample_size=10000)

# %% [markdown]
# Let's look at the model's learned weights. Conditional distributions are easier to visualize:

# %%
fig, ax = plt.subplots(1, 2)
fig.tight_layout()

ax[0].imshow(bigram_model.P)
ax[0].set_title("Counting")
ax[1].imshow(P_nn.data)
ax[1].set_title("NN");

# %% [markdown]
# It looks like the neural net recovered something very similar to the true count matrix!

# %% [markdown]
# ### Regularization

# %% [markdown]
# Observe that smoothing the count matrix approximates to it having constant entries. In the context of the neural net model, this means having a zero weight matrix so that the resulting count matrix `W.exp()` is a matrix of ones. So the more getting zero weights is incentivized in the loss function, the more uniform the resulting distribution is. This is precisely weight **regularization**. For example, we can add $\frac{\alpha}{n}\lVert \boldsymbol{\mathsf W} \rVert^2_2$ where $n = |\boldsymbol{\mathsf W}|$ to the loss function:
#
# ```python
# loss += 0.1 * model.W.square().mean()
# ```
#
# This acts like a force that pushes the weights to zero whenever its magnitude increases to try to reduce the NLL loss.

# %% [markdown]
# ## Appendix: Exercises

# %% [markdown]
# ### Exercise 1
#
# Train a trigram language model, i.e. take two characters as an input to predict the 3rd one. Feel free to use either counting or a neural net. Evaluate the loss. Did it improve over a bigram model?

# %% [markdown]
# **Solution.** A neural net model seems more straightforward to implement.

# %%
from itertools import product

xs, ys = build_dataset(context_size=2)
xs = torch.tensor(xs)
ys = torch.tensor(ys)

for i in range(5):
    print(f"{itox(2)[xs[i].item()]}  ->  {itos[ys[i].item()]}")
# Out:
# ..  ->  e
# .e  ->  m
# em  ->  m
# mm  ->  a
# ma  ->  .

# %% [markdown]
# Trigram model just has more input neurons in its hidden layer:

# %%
class TrigramModel:
    def __init__(self, seed=2147483647):
        self.g = torch.Generator().manual_seed(seed)
        self.W = torch.randn((27*27, 27), generator=self.g, requires_grad=True)

    def __call__(self, xs):
        xenc = F.one_hot(xs, num_classes=27*27).float()
        logits = xenc @ self.W
        counts = logits.exp()
        probs = counts / counts.sum(1, keepdim=True)
        return probs
        
    def zero_grad(self):
        self.W.grad = None

    def optim_step(self, lr):
        self.W.data -= lr * self.W.grad

# %% [markdown]
# Model training:

# %%
import torch.nn.functional as F
def train_model(model, xs, ys, num_steps=100, lr=100.0):
    for k in range(num_steps):
        probs = model(xs)
        loss = -probs[torch.arange(len(ys)), ys].log().mean()

        model.zero_grad()
        loss.backward()
        model.optim_step(lr=lr)

        # logging
        losses.append(loss.item())
        if k % 10 == 9:
            print(f"[{k+1:>03d}/{num_steps}]   loss={loss:.4f}")

    return losses


model = TrigramModel()
train_model(model, xs, ys);

# %% [markdown]
# It improved! (Previous best is `nll=2.4863`).

# %% [markdown]
# ### Exercise 2
#
# Split up the dataset randomly into 80% train set, 10% dev set, 10% test set. Train the bigram and trigram models only on the training set. Evaluate them on dev and test splits. What can you see?

# %% [markdown]
# **Solution.** Modifying our training function to include testing and validation:

# %%
def nll_loss(model, xs, ys):
    probs = model(xs)
    n = len(ys)
    return -probs[torch.arange(n), ys].log().mean()


def train_model(
        model, 
        xs, ys, 
        xs_dev, ys_dev, 
        xs_tst, ys_tst,
        num_steps=100, 
        lr=100.0,
        loss_fn=nll_loss,
        eval_fn=None,
        verbose=True
    ):
    
    if eval_fn is None:
        eval_fn = loss_fn

    losses_trn = {}
    losses_dev = {}

    for k in range(num_steps):
        loss = loss_fn(model, xs, ys)

        model.zero_grad()
        loss.backward()
        model.optim_step(lr=lr)

        # logging
        losses_trn[k] = loss.item()
        if k % 10 == 9:
            loss_dev = eval_fn(model, xs_dev, ys_dev)
            losses_dev[k] = loss_dev.item()
            if verbose:
                print(f"[{k+1:>03d}/{num_steps}]    loss={loss:.4f}    dev_loss={loss_dev:.4f}")
    
    loss_test = eval_fn(model, xs_tst, ys_tst).item()
    if verbose:
        print(f'test_loss={loss_test:.4f}')
    
    return {"loss_trn": losses_trn, "loss_dev": losses_dev, "loss_tst": loss_test}

# %% [markdown]
# Since our approach is to predict next characters, we want to stratify based on a balanced distribution of next characters over the splits.

# %%
from sklearn.model_selection import StratifiedKFold

def create_folds(xs, ys, seed=42):
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
    folds = torch.zeros_like(xs)
    for fold, (trn_, val_) in enumerate(kf.split(xs, ys)):
        folds[val_] = fold

    xs_trn, ys_trn = xs[folds >  1], ys[folds >  1]
    xs_dev, ys_dev = xs[folds == 1], ys[folds == 1]
    xs_tst, ys_tst = xs[folds == 0], ys[folds == 0]

    return xs_trn, ys_trn, xs_dev, ys_dev, xs_tst, ys_tst

# %% [markdown]
# Let us look at the previous bigram NN model.

# %%
xs_, ys_ = build_dataset(context_size=1)
xs_ = torch.tensor(xs_)
ys_ = torch.tensor(ys_)

print("Bigram model training:")
hist_bigram = train_model(
    NNBigramModel(), 
    *create_folds(xs_, ys_)
)
# Out:
# Bigram model training:
# [010/100]    loss=2.6099    dev_loss=2.6046
# [020/100]    loss=2.5352    dev_loss=2.5258
# [030/100]    loss=2.5170    dev_loss=2.5255
# [040/100]    loss=2.5033    dev_loss=2.4971
# [050/100]    loss=2.5013    dev_loss=2.5111
# [060/100]    loss=2.4939    dev_loss=2.4880
# [070/100]    loss=2.4951    dev_loss=2.5053
# [080/100]    loss=2.4895    dev_loss=2.4838
# [090/100]    loss=2.4919    dev_loss=2.5022
# [100/100]    loss=2.4871    dev_loss=2.4815
# test_loss=2.4920

# %% [markdown]
# Comparing this with the trigram model:

# %%
xs, ys = build_dataset(context_size=2)
xs = torch.tensor(xs)
ys = torch.tensor(ys)

xs_trn, ys_trn, \
xs_dev, ys_dev, \
xs_tst, ys_tst = create_folds(xs, ys)

print("Trigram model training:")
hist_trigram = train_model(
    TrigramModel(),
    xs_trn, ys_trn, 
    xs_dev, ys_dev, 
    xs_tst, ys_tst
)
# Out:
# Trigram model training:
# [010/100]    loss=2.9966    dev_loss=2.9674
# [020/100]    loss=2.7558    dev_loss=2.7458
# [030/100]    loss=2.6372    dev_loss=2.6335
# [040/100]    loss=2.5632    dev_loss=2.5623
# [050/100]    loss=2.5112    dev_loss=2.5119
# [060/100]    loss=2.4724    dev_loss=2.4740
# [070/100]    loss=2.4422    dev_loss=2.4445
# [080/100]    loss=2.4180    dev_loss=2.4208
# [090/100]    loss=2.3982    dev_loss=2.4014
# [100/100]    loss=2.3817    dev_loss=2.3852
# test_loss=2.4003

# %%
plt.plot(hist_bigram ['loss_trn'].keys(), hist_bigram ['loss_trn'].values(), color=f'C0', label="2-gram (train)", linestyle='dashed')
plt.plot(hist_bigram ['loss_dev'].keys(), hist_bigram ['loss_dev'].values(), color=f'C0', label="2-gram (dev)")
plt.plot(hist_trigram['loss_trn'].keys(), hist_trigram['loss_trn'].values(), color=f'C1', label="3-gram (train)", linestyle='dashed')
plt.plot(hist_trigram['loss_dev'].keys(), hist_trigram['loss_dev'].values(), color=f'C1', label="3-gram (dev)")

plt.ylabel('NLL')
plt.xlabel('epochs')
plt.legend();

# %% [markdown]
# Using trigrams seem to result in better generalization. This can be expected since trigrams include more context (i.e. one more character) to predict the next word. Although, the trigram model is more difficult to train as it requires learning $27^3$ probabilities. Indeed, we see from the loss curves that the trigram model converges more slowly!

# %% [markdown]
# ### Exercise 4 & 5

# %% [markdown]
# *a*) Our 1-hot vectors merely select a row of `W`, so producing these vectors explicitly feels wasteful. Can you delete our use of `F.one_hot` in favor of simply indexing into rows of `W`? *b*) Look up and use `F.cross_entropy` instead. You should achieve the same result. Can you think of why we would prefer to use this instead than the usual NLL loss? &nbsp;
#
# **Solution.** Exercise 3 requires tuning, so we start with this exercise first to get faster models. Our solution is to simply index the rows of the weights matrix using the input tensor of indices, and use `F.cross_entropy` on the logits.

# %%
class TrigramModelEfficient:
    def __init__(self, seed=2147483647):
        self.g = torch.Generator().manual_seed(seed)
        self.W = torch.randn((27*27, 27), generator=self.g, requires_grad=True)

    def __call__(self, xs: list[int]) -> list[float]:
        logits = self.W[xs]
        return logits
        
    def zero_grad(self):
        self.W.grad = None

    def optim_step(self, lr):
        self.W.data -= lr * self.W.grad


def cross_entropy_loss(model, xs, ys):
    return F.cross_entropy(model(xs), ys)


trigram_model = TrigramModelEfficient()
train_model(
    trigram_model, 
    xs_trn, ys_trn, 
    xs_dev, ys_dev, 
    xs_tst, ys_tst,
    loss_fn=cross_entropy_loss,
);
# Out:
# [010/100]    loss=2.9966    dev_loss=2.9674
# [020/100]    loss=2.7558    dev_loss=2.7458
# [030/100]    loss=2.6372    dev_loss=2.6335
# [040/100]    loss=2.5632    dev_loss=2.5623
# [050/100]    loss=2.5112    dev_loss=2.5119
# [060/100]    loss=2.4724    dev_loss=2.4740
# [070/100]    loss=2.4422    dev_loss=2.4445
# [080/100]    loss=2.4180    dev_loss=2.4208
# [090/100]    loss=2.3982    dev_loss=2.4014
# [100/100]    loss=2.3817    dev_loss=2.3852
# test_loss=2.4003

# %% [markdown]
# **a**) Note that this is precisely the same results as in the implementation of the trigram model above (Exercise 2). This also shows that applying `F.cross_entropy` to the logits is equivalent to NLL with softmax probabilities. But this is super fast: 10x faster than the previous implementation.
#
# **b**) Using cross-entropy loss on logits is more numerically stable. Observe that with a softmax layer, we can add any constant to the logits without affecting the result. Hence, we can subtract the largest logit ${\mathsf s}_{j^*}$ so that the largest exponential is 1, avoiding overflow (even if other terms underflow):
#
# $$
# \begin{aligned}
# \log \left( \frac {e^{\mathsf s_i}}{\sum_{j} e^{\mathsf s_j}} \right)
# &= {\mathsf s}_i - \log \left( {\sum_{j} e^{\mathsf s_j}} \right) \\
# &= {\mathsf s}_i - {\mathsf s}_{j^*} - \log \left( \sum_{j} e^{{\mathsf s}_j - {\mathsf s}_{j^*}} \right).
# \end{aligned}$$
#
# Note that directly using this formula and the corresponding formula for backward results to faster forward and backward passes (e.g. reducing the number of nodes to traverse when constructing gradients). Observe also that division is avoided and that only the target index of the softmax has to be computed by `F.cross_entropy`. This makes training more efficient.

# %%
bad_logits = torch.tensor([100., 20., 1., -200])
probs = bad_logits.exp() / bad_logits.exp().sum()
print(probs.numpy())

probs = (bad_logits - 100).exp() / (bad_logits - 100).exp().sum()
print(probs.numpy())
# Out:
# [nan  0.  0.  0.]
# [1.0000000e+00 1.8048513e-35 1.0089349e-43 0.0000000e+00]

# %% [markdown]
# On the other hand, `F.cross_entropy` just works:

# %%
F.cross_entropy(bad_logits, target=torch.tensor(0))
# Out:
# tensor(0.)

# %% [markdown]
# ### Exercise 3
#
# Use the dev set to tune the strength of smoothing (or regularization) for the trigram model &mdash; i.e. try many possibilities and see which one works best based on the dev set loss. What patterns can you see in the train and dev set loss as you tune this strength? Take the best setting of the smoothing and evaluate on the test set once and at the end. How good of a loss do you achieve?

# %% [markdown]
# **Solution.** We define a function that adds regularization to the loss. Note that we still use NLL loss for evaluation.

# %%
from functools import partial

def regularized_ce_loss(model, xs, ys, alpha):
    loss = cross_entropy_loss(model, xs, ys)
    reg = alpha * model.W.square().mean()
    return loss + reg
    

for i, alpha in enumerate([0.001, 0.01, 0.1, 1.0, 10.0, 100.0]):
    model = TrigramModelEfficient()
    history = train_model(
        model, 
        xs_trn, ys_trn, 
        xs_dev, ys_dev, 
        xs_tst, ys_tst,
        loss_fn=partial(regularized_ce_loss, alpha=alpha),
        eval_fn=cross_entropy_loss,
        verbose=False
    )
    plt.plot(history['loss_dev'].keys(), history['loss_dev'].values(), color=f'C{i}', label=r'$\alpha$='+f"{alpha}")
    print(f"test_nll={history['loss_tst']:.4f}") # Not including reg.
    
plt.ylabel('NLL')
plt.xlabel('epochs')
plt.legend();
# Out:
# test_nll=2.4003
# test_nll=2.4001
# test_nll=2.3993
# test_nll=2.4391
# test_nll=2.8024
# test_nll=3.2009

# %% [markdown]
# As discussed above, the stronger the regularization, the more uniform the output distributions become. Hence, we tend to get worse performing models. Indeed, we see that the test loss generally converges to worse values as we increase $\alpha$ which controls the strength of regularization. It approaches the NLL for a model that assigns the same probability to all ${n}$ characters, i.e. $-\log \frac{1}{{n}} = \log {n}.$

# %%
math.log(27.0)
# Out:
# 3.295836866004329
